# %%
import pickle
import os

# For running it locally
if os.getcwd().startswith("/home/lakrids"):
    path_prefix = "/home/lakrids/GenomeDK"
else:
    path_prefix = "/faststorage/project"

# %%
species = "Panthera_leo"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '5.42e-9', 'generation': '6', 'biogeography': 'Afrotropical', 'het': '0.00086'}

# %%
params = {"mu":"5.42e-9", "generation": "6", "biogeography": "Afrotropical", "het": "0.00086"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Panthera_tigris"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '8.10e-9', 'generation': '8', 'biogeography': 'Indomalayan', 'het': '0.00064'}

# %%
params = {"mu":"8.10e-9", "generation": "8", "biogeography": "Indomalayan","het": "0.00064"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Panthera_uncia"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '4.94e-9', 'generation': '8', 'biogeography': 'Palearctic', 'het': '0.00017'}

# %%
params = {"mu":"4.94e-9", "generation": "8", "biogeography": "Palearctic","het": "0.00017"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Panthera_pardus"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '8.26e-9', 'generation': '9.316836', 'biogeography': 'Afrotropical', 'het': '0.00151'}

# %%
params = {"mu":"8.26e-9", "generation": "9.316836", "biogeography": "Afrotropical", "het": "0.00151"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Elephas_maximus"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '5.3e-9', 'generation': '22', 'biogeography': 'Indomalayan', 'het': '0.00096'}

# %%
params = {"mu":"5.3e-9", "generation": "22", "biogeography": "Indomalayan", "het": "0.00096"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Rhinoceros_unicornis"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '3.9e-8', 'generation': '18.77257', 'biogeography': 'Indomalayan', 'het': '0.00057'}

# %%
params = {"mu":"3.9e-8", "generation": "18.77257", "biogeography": "Indomalayan", "het": "0.00057"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Ceratotherium_simum"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '2.4e-8', 'generation': '18.80917', 'biogeography': 'Afrotropical', 'het': '0.00062'}

# %%
params = {"mu":"2.4e-8", "generation": "18.80917", "biogeography": "Afrotropical", "het": "0.00062"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Diceros_bicornis"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '2.1e-8', 'generation': '17', 'biogeography': 'Afrotropical', 'het': '0.00091'}

# %%
params = {"mu":"2.1e-8", "generation": "17", "biogeography": "Afrotropical", "het": "0.00091"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Loxodonta_africana"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '3.9e-9', 'generation': '25', 'biogeography': 'Afrotropical', 'het': '0.00092'}

# %%
params = {"mu":"3.9e-9", "generation": "25", "biogeography": "Afrotropical", "het": "0.00092"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Loxodonta_cyclotis"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '3.9e-9', 'generation': '31', 'biogeography': 'Afrotropical', 'het': '0.00340'}

# %%
params = {"mu":"3.9e-9", "generation": "31", "biogeography": "Afrotropical", "het": "0.00340"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Boselaphus_tragocamelus"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '1.5e-8', 'generation': '7.5', 'biogeography': 'Indomalayan', 'het': '0.00146'}

# %%
params = {"mu":"1.5e-8", "generation": "7.5", "biogeography": "Indomalayan", "het": "0.00146"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
import seaborn as sns
Panthera_leo = sns.color_palette("husl",12)[0]
Panthera_tigris = sns.color_palette("husl",12)[1]
Panthera_pardus = sns.color_palette("husl",12)[2]
Panthera_uncia = sns.color_palette("husl",12)[3]
Boselaphus_tragocamelus = sns.color_palette("husl",12)[4]
Elephas_maximus = sns.color_palette("husl",12)[5]
Loxodonta_africana = sns.color_palette("husl",12)[6]
Loxodonta_cyclotis = sns.color_palette("husl",12)[7]
Rhinoceros_unicornis = sns.color_palette("husl",12)[8]
Diceros_bicornis = sns.color_palette("husl",12)[9]
Ceratotherium_simum = sns.color_palette("husl",12)[10]
sns.color_palette("husl",12)[1]
# Out:
# (0.903599057664843, 0.511987276335809, 0.19588350060161624)
