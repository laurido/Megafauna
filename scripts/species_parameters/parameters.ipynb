# %%
import pickle
import os

# For running it locally
if os.getcwd().startswith("/home/lakrids"):
    path_prefix = "/home/lakrids/GenomeDK"
else:
    path_prefix = "/faststorage/project"
# Out:
# {'mu': '5.42e-9', 'generation': '5', 'colour': (0.9677975592919913, 0.44127456009157356, 0.5358103155058701)}

# %%
species = "Panthera_leo"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '5.42e-9', 'generation': '5', 'biogeo': 'Afrotropical'}

# %%
params = {"mu":"5.42e-9", "generation": "5", "biogeography": "Afrotropical"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Panthera_tigris"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '8.10e-9', 'generation': '8', 'biogeography': 'Indomalayan'}

# %%
params = {"mu":"8.10e-9", "generation": "8", "biogeography": "Indomalayan"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Panthera_uncia"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '4.94e-9', 'generation': '5', 'biogeography': 'Palearctic'}

# %%
params = {"mu":"4.94e-9", "generation": "5", "biogeography": "Palearctic"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Panthera_pardus"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '8.26e-9', 'generation': '7.5', 'biogeography': 'Afrotropical'}

# %%
params = {"mu":"8.26e-9", "generation": "7.5", "biogeography": "Afrotropical"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Elephas_maximus"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '5.3e-9', 'generation': '31', 'biogeography': 'Indomalayan'}

# %%
params = {"mu":"5.3e-9", "generation": "31", "biogeography": "Indomalayan"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Rhinoceros_unicornis"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '3.9e-8', 'generation': '12', 'biogeography': 'Indomalayan'}

# %%
params = {"mu":"3.9e-8", "generation": "12", "biogeography": "Indomalayan"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Ceratotherium_simum"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '2.4e-8', 'generation': '27', 'biogeography': 'Afrotropical'}

# %%
params = {"mu":"2.4e-8", "generation": "27", "biogeography": "Afrotropical"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Diceros_bicornis"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '2.1e-8', 'generation': '24', 'biogeography': 'Afrotropical'}

# %%
params = {"mu":"2.1e-8", "generation": "24", "biogeography": "Afrotropical"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Loxodonta_africana"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '3.9e-9', 'generation': '24', 'biogeography': 'Afrotropical'}

# %%
params = {"mu":"3.9e-9", "generation": "24", "biogeography": "Afrotropical"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Loxodonta_cyclotis"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '3.9e-9', 'generation': '31', 'biogeography': 'Afrotropical'}

# %%
params = {"mu":"3.9e-9", "generation": "31", "biogeography": "Afrotropical"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
species = "Boselaphus_tragocamelus"

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "rb") as f: 
        params = pickle.load(f)
print(params)
# Out:
# {'mu': '1.5e-8', 'generation': '7.5', 'biogeography': 'Indomalayan'}

# %%
params = {"mu":"1.5e-8", "generation": "7.5", "biogeography": "Indomalayan"}

with open(f"{path_prefix}/megaFauna/sa_megafauna/results/{species}/parameters_{species}.pkl", "wb") as f:
    pickle.dump(params, f)

# %%
import seaborn as sns
Panthera_leo = sns.color_palette("husl",12)[0]
Panthera_tigris = sns.color_palette("husl",12)[1]
Panthera_pardus = sns.color_palette("husl",12)[2]
Panthera_uncia = sns.color_palette("husl",12)[3]
Boselaphus_tragocamelus = sns.color_palette("husl",12)[4]
Elephas_maximus = sns.color_palette("husl",12)[5]
Loxodonta_africana = sns.color_palette("husl",12)[6]
Loxodonta_cyclotis = sns.color_palette("husl",12)[7]
Rhinoceros_unicornis = sns.color_palette("husl",12)[8]
Diceros_bicornis = sns.color_palette("husl",12)[9]
Ceratotherium_simum = sns.color_palette("husl",12)[10]
sns.color_palette("husl",12)[1]
# Out:
# (0.903599057664843, 0.511987276335809, 0.19588350060161624)
